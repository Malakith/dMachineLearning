# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

#data = np.load("tensorflow_python_files\simple_network\simple_network_params.npy")
data = np.load("tensorflow_python_files\convNetwork_higherlearningrate\ConvoNetwork_highlearningrate.npy")
print(data)


fig = plt.figure()
fig.set_size_inches(8, 2.5)
plt.ylabel("Accuracy")
plt.xlabel("Iteration")

line_in, = plt.plot(data[:,0], data[:,1], ':', color="red", label= "Training accuracy")
line_out, = plt.plot(data[:,0], data[:,2], '--', color="blue", label= "Validation accuracy")
out_max = plt.plot(data[np.argmax( data[:,2] ), 0], np.max(data[:,2]), '^', color="blue", label="Validation accuracy max = %2.2f" % np.max(data[:,2]))
plt.legend(handles=[line_in, line_out], loc=4, numpoints=1)
plt.show()
    
# print best 
print("OoS max = %0.4f, with Is = %0.4f, for iteration = %i" %  ( np.max(data[:,2]), 
                                            data[np.argmax( data[:,2] ), 1],
                                            data[np.argmax( data[:,2] ), 0]) )
# Out:
# [[     0.             13.28125        13.21705426]
#  [   100.             94.3359375      92.63565891]
#  [   200.             98.046875       95.03875969]
#  [   300.             96.6796875      96.1627907 ]
#  [   400.             98.6328125      96.89922481]
#  [   500.             98.4375         97.28682171]
#  [   600.             98.828125       97.51937984]
#  [   700.             98.828125       97.51937984]
#  [   800.             99.4140625      97.63565891]
#  [   900.             99.21875        97.86821705]
#  [  1000.             98.828125       97.79069767]
#  [  1100.             99.21875        97.90697674]
#  [  1200.             99.4140625      98.10077519]
#  [  1300.             99.609375       97.82945736]
#  [  1400.             99.8046875      97.94573643]
#  [  1500.             99.4140625      97.79069767]
#  [  1600.             99.8046875      98.0620155 ]
#  [  1700.            100.             97.94573643]
#  [  1800.             99.609375       97.94573643]
#  [  1900.            100.             97.86821705]
#  [  2000.             99.4140625      97.98449612]
#  [  2100.             99.8046875      98.13953488]
#  [  2200.             99.8046875      98.13953488]
#  [  2300.             99.8046875      98.21705426]
#  [  2400.             99.8046875      97.94573643]
#  [  2500.            100.             98.13953488]
#  [  2600.             99.4140625      98.02325581]
#  [  2700.            100.             98.10077519]
#  [  2800.            100.             98.02325581]
#  [  2900.            100.             98.17829457]
#  [  3000.             99.8046875      98.13953488]
#  [  3100.             99.609375       98.10077519]
#  [  3200.            100.             98.17829457]
#  [  3300.            100.             98.13953488]
#  [  3400.            100.             98.0620155 ]
#  [  3500.             99.609375       98.10077519]
#  [  3600.            100.             98.10077519]
#  [  3700.            100.             98.13953488]
#  [  3800.            100.             98.0620155 ]
#  [  3900.            100.             98.10077519]
#  [  4000.             99.8046875      98.13953488]
#  [  4100.            100.             98.17829457]
#  [  4200.            100.             98.0620155 ]
#  [  4300.             99.8046875      98.13953488]
#  [  4400.            100.             98.10077519]
#  [  4500.            100.             98.17829457]
#  [  4600.            100.             98.17829457]
#  [  4700.            100.             98.10077519]
#  [  4800.            100.             98.17829457]
#  [  4900.            100.             98.13953488]
#  [  5000.            100.             98.17829457]
#  [  5100.            100.             98.17829457]
#  [  5200.            100.             98.10077519]
#  [  5300.             99.8046875      98.13953488]
#  [  5400.            100.             98.13953488]
#  [  5500.            100.             98.17829457]
#  [  5600.             99.8046875      98.21705426]
#  [  5700.            100.             98.21705426]
#  [  5800.            100.             98.17829457]
#  [  5900.            100.             98.17829457]
#  [  6000.            100.             98.17829457]
#  [  6100.            100.             98.13953488]
#  [  6200.            100.             98.17829457]
#  [  6300.            100.             98.17829457]
#  [  6400.            100.             98.21705426]
#  [  6500.            100.             98.13953488]
#  [  6600.             99.8046875      98.17829457]
#  [  6700.            100.             98.17829457]
#  [  6800.            100.             98.13953488]
#  [  6900.            100.             98.17829457]
#  [  7000.            100.             98.13953488]
#  [  7100.            100.             98.21705426]
#  [  7200.            100.             98.17829457]
#  [  7300.            100.             98.17829457]
#  [  7400.            100.             98.13953488]
#  [  7500.            100.             98.17829457]
#  [  7600.            100.             98.17829457]
#  [  7700.            100.             98.17829457]
#  [  7800.            100.             98.17829457]
#  [  7900.            100.             98.17829457]
#  [  8000.             99.8046875      98.17829457]
#  [  8100.            100.             98.17829457]
#  [  8200.            100.             98.17829457]
#  [  8300.            100.             98.13953488]
#  [  8400.            100.             98.13953488]
#  [  8500.            100.             98.13953488]
#  [  8600.            100.             98.17829457]
#  [  8700.             99.8046875      98.13953488]
#  [  8800.            100.             98.13953488]
#  [  8900.            100.             98.17829457]
#  [  9000.            100.             98.17829457]
#  [  9100.            100.             98.17829457]
#  [  9200.            100.             98.17829457]
#  [  9300.            100.             98.17829457]
#  [  9400.            100.             98.17829457]
#  [  9500.            100.             98.13953488]
#  [  9600.            100.             98.17829457]
#  [  9700.            100.             98.13953488]
#  [  9800.            100.             98.13953488]
#  [  9900.             99.8046875      98.17829457]
#  [ 10000.            100.             98.13953488]]
# OoS max = 98.2171, with Is = 99.8047, for iteration = 2300
