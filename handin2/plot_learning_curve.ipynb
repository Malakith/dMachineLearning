# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

#data = np.load("tensorflow_python_files\simple_network\simple_network_params.npy")
#data = np.load("tensorflow_python_files\convNetwork_higherlearningrate\ConvoNetwork_highlearningrate.npy")
data = np.load("tensorflow_python_files\convolutionalNetwork\ConvoNetwork.npy")
print(data)


fig = plt.figure()
fig.set_size_inches(8, 2.5)
plt.ylabel("Accuracy")
plt.xlabel("Iteration")

line_in, = plt.plot(data[:,0], data[:,1], ':', color="red", label= "Training accuracy")
line_out, = plt.plot(data[:,0], data[:,2], '--', color="blue", label= "Validation accuracy")
out_max = plt.plot(data[np.argmax( data[:,2] ), 0], np.max(data[:,2]), '^', color="blue", label="Validation accuracy max = %2.2f" % np.max(data[:,2]))
plt.legend(handles=[line_in, line_out], loc=4, numpoints=1)
plt.show()
    
# print best 
print("OoS max = %0.4f, with Is = %0.4f, for iteration = %i" %  ( np.max(data[:,2]), 
                                            data[np.argmax( data[:,2] ), 1],
                                            data[np.argmax( data[:,2] ), 0]) )
# Out:
# [[  0.00000000e+00   9.57031250e+00   1.00000000e+01]
#  [  1.00000000e+02   9.02343750e+01   8.52325581e+01]
#  [  2.00000000e+02   9.17968750e+01   9.18604651e+01]
#  [  3.00000000e+02   9.47265625e+01   9.36046512e+01]
#  [  4.00000000e+02   9.80468750e+01   9.44573643e+01]
#  [  5.00000000e+02   9.64843750e+01   9.50387597e+01]
#  [  6.00000000e+02   9.60937500e+01   9.48062016e+01]
#  [  7.00000000e+02   9.53125000e+01   9.51937984e+01]
#  [  8.00000000e+02   9.82421875e+01   9.56976744e+01]
#  [  9.00000000e+02   9.82421875e+01   9.57364341e+01]
#  [  1.00000000e+03   9.80468750e+01   9.59689922e+01]
#  [  1.10000000e+03   9.82421875e+01   9.61240310e+01]
#  [  1.20000000e+03   9.80468750e+01   9.57751938e+01]
#  [  1.30000000e+03   9.84375000e+01   9.56589147e+01]
#  [  1.40000000e+03   9.84375000e+01   9.63953488e+01]
#  [  1.50000000e+03   9.76562500e+01   9.65116279e+01]
#  [  1.60000000e+03   9.82421875e+01   9.62403101e+01]
# ...
